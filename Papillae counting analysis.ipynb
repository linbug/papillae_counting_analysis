# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
cd C:\Users\Admin\Dropbox\Postgrad\Research\Basal Land Plants\Marchantia\Transformation\
# Out:
# C:\Users\Admin\Dropbox\Postgrad\Research\Basal Land Plants\Marchantia\Transformation

# %%
papillae_data = pd.read_excel("papillae counting analysis.xlsx")

# %%
sns.boxplot(papillae_data["Papillae per 100uMsq"], groupby = papillae_data["Line"] )

# %%
CaMV35_only= papillae_data[~papillae_data["Line"].isin(["EFOE B","EFOE C"])]
colors = ["#4C72B0", "#4C72B0", "#4C72B0", "#4C72B0","#C44E52"]
sns.boxplot(CaMV35_only["Papillae per 100uMsq"], groupby = CaMV35_only["Line"], color = colors )

# %%
EF_only= papillae_data[papillae_data["Line"].isin(["EFOE B","EFOE C", "Wt"])]
colors = ["#55A868","#55A868","#C44E52"]
sns.boxplot(EF_only["Papillae per 100uMsq"], groupby = EF_only["Line"], color = colors)
